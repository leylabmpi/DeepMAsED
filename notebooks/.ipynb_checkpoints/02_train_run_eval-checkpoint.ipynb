# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#DM-run" data-toc-modified-id="DM-run-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>DM run</a></span></li><li><span><a href="#Communites" data-toc-modified-id="Communites-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Communites</a></span><ul class="toc-item"><li><span><a href="#n1000_r3" data-toc-modified-id="n1000_r3-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>n1000_r3</a></span></li><li><span><a href="#n1000_r30" data-toc-modified-id="n1000_r30-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>n1000_r30</a></span></li></ul></li><li><span><a href="#Estimated-coverage" data-toc-modified-id="Estimated-coverage-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Estimated coverage</a></span></li><li><span><a href="#Feature-tables" data-toc-modified-id="Feature-tables-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Feature tables</a></span><ul class="toc-item"><li><span><a href="#n1000_r3" data-toc-modified-id="n1000_r3-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>n1000_r3</a></span><ul class="toc-item"><li><span><a href="#MetaQUAST-classifications" data-toc-modified-id="MetaQUAST-classifications-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>MetaQUAST classifications</a></span></li><li><span><a href="#SNPs-~-coverage" data-toc-modified-id="SNPs-~-coverage-7.1.2"><span class="toc-item-num">7.1.2&nbsp;&nbsp;</span>SNPs ~ coverage</a></span></li></ul></li><li><span><a href="#n1000_r30" data-toc-modified-id="n1000_r30-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>n1000_r30</a></span><ul class="toc-item"><li><span><a href="#SNPs-~-coverage" data-toc-modified-id="SNPs-~-coverage-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>SNPs ~ coverage</a></span></li></ul></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * evaluate the results of the training dataset run

# %% [markdown]
# # Var

# %%
# location of all training dataset runs
work_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs/'
# 1000 ref genomes, 3 metagenomes
n1000_r3_dir = file.path(work_dir, 'n1000_r3')
# 1000 ref genomes, 30 metagenomes
n1000_r30_dir = file.path(work_dir, 'n1000_r30')

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)

source('/ebio/abt3_projects/software/dev/DeepMAsED/bin/misc_r_functions/init.R')

# %% [markdown]
# # DM run

# %%
# pipeline run config files
cat_file(file.path(n1000_r3_dir, 'config.yaml'))
# Out:
# # Input
# genomes_file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/GTDB_ref_genomes/DeepMAsED_GTDB_genome-refs_train.tsv
#
# # Output location
# output_dir: /ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs/n1000_r3/
#
#
# # software parameters
# # Use "Skip" to skip  steps. If no params for rule, use ""
# params:
#   # simulating metagenomes
#   reps: 3
#   MGSIM:
#     genome_download: ""
#     communities: --richness 1
#     reads: --sr-seq-depth 1e6 --art-paired --art-mflen 250
#   # assemblying metagenomes
#   assemblers:
#     metaspades: -k auto --only-assembler
#     megahit: --min-count 3 --min-contig-len 1000 --presets meta-sensitive
#     idba_ud: Skip #--mink 20 --maxk 100
#     ray: Skip
#   # assembly filtering
#   contig_length_cutoff: 1000       # length in bp
#   # assessing assembly errors
#   minimap2: ""
#   metaquast: --min-identity 95 --extensive-mis-size 100 --no-icarus --max-ref-number 0
#   # mapping reads to contigs
#   samtools: ""
#   # creating DL features
#   make_features: ""
#
# # snakemake pipeline
# pipeline:
#   snakemake_folder: ./
#   script_folder: ./bin/scripts/
#   temp_folder: /tmp/global/

# %%
# pipeline run config files
cat_file(file.path(n1000_r30_dir, 'config.yaml'))
# Out:
# # Input
# genomes_file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/GTDB_ref_genomes/DeepMAsED_GTDB_genome-refs_train.tsv
#
# # Output location
# output_dir: /ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs/n1000_r30/
#
#
# # software parameters
# # Use "Skip" to skip  steps. If no params for rule, use ""
# params:
#   # simulating metagenomes
#   reps: 30
#   MGSIM:
#     genome_download: ""
#     communities: --richness 1
#     reads: --sr-seq-depth 1e6 --art-paired --art-mflen 250
#   # assemblying metagenomes
#   assemblers:
#     metaspades: -k auto --only-assembler
#     megahit: --min-count 3 --min-contig-len 1000 --presets meta-sensitive
#     idba_ud: Skip #--mink 20 --maxk 100
#     ray: Skip
#   # assembly filtering
#   contig_length_cutoff: 1000       # length in bp
#   # assessing assembly errors
#   minimap2: ""
#   metaquast: --min-identity 95 --extensive-mis-size 100 --no-icarus --max-ref-number 0
#   # mapping reads to contigs
#   samtools: ""
#   # creating DL features
#   make_features: ""
#
# # snakemake pipeline
# pipeline:
#   snakemake_folder: ./
#   script_folder: ./bin/scripts/
#   temp_folder: /tmp/global2/

# %% [markdown]
# # Communites
#
# * Simulated abundances of each ref genome

# %% [markdown]
# ## n1000_r3

# %%
comm_files = list.files(file.path(n1000_r3_dir, 'MGSIM'), 'comm_wAbund.txt', full.names=TRUE, recursive=TRUE)
comm_files
# Out:
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/MGSIM/1/comm_wAbund.txt"
# [2] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/MGSIM/2/comm_wAbund.txt"
# [3] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/MGSIM/3/comm_wAbund.txt"

# %%
comms = list()
for(F in comm_files){
    df = read.delim(F, sep='\t')
    df$Rep = basename(dirname(F))
    comms[[F]] = df
}
comms = do.call(rbind, comms)
rownames(comms) = 1:nrow(comms)
comms %>% dfhead
# Out:
# [1] 3000    5
#   Community Taxon
# 1 1         GB_GCA_001311865_1_Piscibacillus_salipiscarius_JCM_13188
# 2 1         RS_GCF_002743175_1_Sporosarcina_sp_P20a
# 3 1         RS_GCF_900107435_1_Herbiconiux_ginsengi
#   Perc_rel_abund Rank Rep
# 1 4.945330       1    1
# 2 4.319948       2    1
# 3 2.845880       3    1

# %%
comms$Perc_rel_abund %>% summary %>% print
p = comms %>%
    group_by(Taxon) %>%
    mutate(mean_Rank = mean(Rank)) %>%
    ungroup() %>%
    mutate(Taxon = reorder(Taxon, mean_Rank)) %>%
    ggplot(aes(Taxon, Perc_rel_abund, color=Rep)) +
    geom_point(size=0.5, alpha=0.4) +
    scale_y_log10() +
    labs(y='% abundance') +
    theme_bw() +
    theme(
        axis.text.x = element_blank()
    )

dims(10,3)
plot(p)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
#  0.000009  0.002770  0.010408  0.100000  0.046236 20.859824
# plot without title

# %%
p = comms %>%
    mutate(Perc_rel_abund = ifelse(Perc_rel_abund == 0, 1e-5, Perc_rel_abund)) %>%
    group_by(Taxon) %>%
    summarize(mean_perc_abund = mean(Perc_rel_abund),
              sd_perc_abund = sd(Perc_rel_abund)) %>%
    ungroup() %>%
    mutate(neg_sd_perc_abund = mean_perc_abund - sd_perc_abund,
           pos_sd_perc_abund = mean_perc_abund + sd_perc_abund,
           neg_sd_perc_abund = ifelse(neg_sd_perc_abund <= 0, 1e-5, neg_sd_perc_abund)) %>%
    mutate(Taxon = Taxon %>% reorder(-mean_perc_abund)) %>%
    ggplot(aes(Taxon, mean_perc_abund)) +
    geom_linerange(aes(ymin=neg_sd_perc_abund, ymax=pos_sd_perc_abund),
                   size=0.3, alpha=0.3) +
    geom_point(size=0.5, alpha=0.4, color='red') +
    labs(y='% abundance') +
    theme_bw() +
    theme(
        axis.text.x = element_blank(),
        panel.grid.major.x = element_blank(), 
        panel.grid.major.y = element_blank(), 
        panel.grid.minor.x = element_blank(),
        panel.grid.minor.y = element_blank()
    )

dims(10,2.5)
plot(p)
# Out:
# plot without title

# %%
dims(10,2.5)
plot(p + scale_y_log10())
# Out:
# plot without title

# %% [markdown]
# ## n1000_r30

# %%
comm_files = list.files(file.path(n1000_r30_dir, 'MGSIM'), 'comm_wAbund.txt', full.names=TRUE, recursive=TRUE)
comm_files %>% length %>% print
comm_files %>% head
# Out:
# [1] 30
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/MGSIM/1/comm_wAbund.txt"
# [2] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/MGSIM/10/comm_wAbund.txt"
# [3] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/MGSIM/11/comm_wAbund.txt"
# [4] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/MGSIM/12/comm_wAbund.txt"
# [5] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/MGSIM/13/comm_wAbund.txt"
# [6] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/MGSIM/14/comm_wAbund.txt"

# %%
comms = list()
for(F in comm_files){
    df = read.delim(F, sep='\t')
    df$Rep = basename(dirname(F))
    comms[[F]] = df
}
comms = do.call(rbind, comms)
rownames(comms) = 1:nrow(comms)
comms %>% dfhead
# Out:
# [1] 30000     5
#   Community Taxon
# 1 1         RS_GCF_001190965_1_Haloferax_gibbonsii
# 2 1         RS_GCF_002797715_1_Diaminobutyricimonas_aerilata
# 3 1         RS_GCF_000478365_1_Herbaspirillum_huttiense_subsp_putei_IAM_15032
#   Perc_rel_abund Rank Rep
# 1 5.234756       1    1
# 2 4.197054       2    1
# 3 3.355024       3    1

# %%
p = comms %>%
    mutate(Perc_rel_abund = ifelse(Perc_rel_abund == 0, 1e-5, Perc_rel_abund)) %>%
    group_by(Taxon) %>%
    summarize(mean_perc_abund = mean(Perc_rel_abund),
              sd_perc_abund = sd(Perc_rel_abund)) %>%
    ungroup() %>%
    mutate(neg_sd_perc_abund = mean_perc_abund - sd_perc_abund,
           pos_sd_perc_abund = mean_perc_abund + sd_perc_abund,
           neg_sd_perc_abund = ifelse(neg_sd_perc_abund <= 0, 1e-5, neg_sd_perc_abund)) %>%
    mutate(Taxon = Taxon %>% reorder(-mean_perc_abund)) %>%
    ggplot(aes(Taxon, mean_perc_abund)) +
    geom_linerange(aes(ymin=neg_sd_perc_abund, ymax=pos_sd_perc_abund),
                   size=0.3, alpha=0.3) +
    geom_point(size=0.5, alpha=0.4, color='red') +
    labs(y='% abundance') +
    theme_bw() +
    theme(
        axis.text.x = element_blank(),
        panel.grid.major.x = element_blank(), 
        panel.grid.major.y = element_blank(), 
        panel.grid.minor.x = element_blank(),
        panel.grid.minor.y = element_blank()
    )

dims(10,2.5)
plot(p)
# Out:
# plot without title

# %%
dims(10,2.5)
plot(p + scale_y_log10())
# Out:
# plot without title

# %% [markdown]
# # Estimated coverage
#
# * Coverage estimated with nonpareil

# %%
F = file.path(n1000_r3_dir, 'coverage', 'nonpareil', 'all_summary.txt')
cov = read.delim(F, sep='\t')
cov %>% summary %>% print
# Out:
#      Sample          C                LR                modelR
#  Min.   :1.0   Min.   :0.2580   Min.   :149442450   Min.   :0.9936
#  1st Qu.:1.5   1st Qu.:0.3253   1st Qu.:149469450   1st Qu.:0.9966
#  Median :2.0   Median :0.3926   Median :149496450   Median :0.9996
#  Mean   :2.0   Mean   :0.3770   Mean   :149505200   Mean   :0.9977
#  3rd Qu.:2.5   3rd Qu.:0.4365   3rd Qu.:149536575   3rd Qu.:0.9997
#  Max.   :3.0   Max.   :0.4803   Max.   :149576700   Max.   :0.9998
#      LRstar            diversity
#  Min.   :8.204e+09   Min.   :18.29
#  1st Qu.:1.118e+10   1st Qu.:18.73
#  Median :1.415e+10   Median :19.18
#  Mean   :1.868e+10   Mean   :19.12
#  3rd Qu.:2.392e+10   3rd Qu.:19.54
#  Max.   :3.368e+10   Max.   :19.90

# %%
F = file.path(n1000_r30_dir, 'coverage', 'nonpareil', 'all_summary.txt')
cov = read.delim(F, sep='\t')
cov %>% summary %>% print
# Out:
#      Sample            C                LR                modelR
#  Min.   : 1.00   Min.   :0.2157   Min.   :149051550   Min.   :0.9949
#  1st Qu.: 8.25   1st Qu.:0.2581   1st Qu.:149451975   1st Qu.:0.9992
#  Median :15.50   Median :0.3133   Median :149493000   Median :0.9997
#  Mean   :15.50   Mean   :0.3193   Mean   :149481875   Mean   :0.9992
#  3rd Qu.:22.75   3rd Qu.:0.3564   3rd Qu.:149568450   3rd Qu.:0.9997
#  Max.   :30.00   Max.   :0.4746   Max.   :149629800   Max.   :0.9998
#      LRstar            diversity
#  Min.   :5.892e+09   Min.   :18.53
#  1st Qu.:1.182e+10   1st Qu.:19.38
#  Median :1.355e+10   Median :19.61
#  Mean   :1.428e+10   Mean   :19.56
#  3rd Qu.:1.530e+10   3rd Qu.:19.90
#  Max.   :3.310e+10   Max.   :20.17

# %% [markdown]
# # Feature tables
#
# * feature tables for ML model training/testing

# %% [markdown]
# ## n1000_r3

# %%
feat_files = list.files(file.path(n1000_r3_dir, 'map'), 'features.tsv.gz', full.names=TRUE, recursive=TRUE)
feat_files %>% length %>% print
feat_files %>% head
# Out:
# [1] 5
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/map/1/metaspades/features.tsv.gz"
# [2] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/map/2/megahit/features.tsv.gz"
# [3] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/map/2/metaspades/features.tsv.gz"
# [4] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/map/3/megahit/features.tsv.gz"
# [5] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r3/map/3/metaspades/features.tsv.gz"

# %%
feats = list()
for(F in feat_files){
    cmd = glue::glue('gunzip -c {F}', F=F)
    df = fread(cmd, sep='\t') %>%
        distinct(contig, assembler, Extensive_misassembly)
    df$Rep = basename(dirname(dirname(F)))
    feats[[F]] = df
}
feats = do.call(rbind, feats)
rownames(feats) = 1:nrow(feats)
feats %>% dfhead
# Out:
# [1] 29891     4
#   contig                             assembler  Extensive_misassembly Rep
# 1 NODE_1000_length_2669_cov_3.082632 metaspades                       1
# 2 NODE_1001_length_2668_cov_2.109453 metaspades                       1
# 3 NODE_1002_length_2667_cov_2.279862 metaspades                       1

# %% [markdown]
# ### MetaQUAST classifications

# %%
p = feats %>%
    mutate(Extensive_misassembly = ifelse(Extensive_misassembly == '', 'None',
                                          Extensive_misassembly)) %>%
    group_by(Extensive_misassembly, assembler, Rep) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Extensive_misassembly, n, color=assembler)) +
    geom_boxplot() +
    scale_y_log10() +
    labs(x='metaQUAST extensive mis-assembly', y='Count') +
    coord_flip() +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

dims(7,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### SNPs ~ coverage

# %%
# loading files; just checking first million lines (should be sufficient)
feats = list()
for(F in feat_files){
    cmd = glue::glue('gunzip -c {F} | head -n 1000000', F=F)
    df = fread(cmd, sep='\t') 
    df$Rep = basename(dirname(dirname(F)))
    feats[[F]] = df
}
feats = do.call(rbind, feats)
rownames(feats) = 1:nrow(feats)
feats %>% dfhead
# Out:
# [1] 4999995      20
#   contig                             assembler  position ref_base num_query_A
# 1 NODE_1000_length_2669_cov_3.082632 metaspades 0        T        0
# 2 NODE_1000_length_2669_cov_3.082632 metaspades 1        C        0
# 3 NODE_1000_length_2669_cov_3.082632 metaspades 2        G        0
#   num_query_C num_query_G num_query_T num_SNPs coverage num_discordant
# 1 0           0           1           0        1        0
# 2 1           0           0           0        1        0
# 3 0           1           0           0        1        0
#   num_supplementary num_secondary chimeric num_hits query_hit_len edit_dist
# 1 0                 0             FALSE    1        2669          2
# 2 0                 0             FALSE    1        2669          2
# 3 0                 0             FALSE    1        2669          2
#   edit_dist_norm Extensive_misassembly Rep
# 1 0.0007493443                         1
# 2 0.0007493443                         1
# 3 0.0007493443                         1

# %%
# general summary
feats %>% summary
# Out:
#     contig           assembler            position        ref_base
#  Length:4999995     Length:4999995     Min.   :     0   Length:4999995
#  Class :character   Class :character   1st Qu.:   763   Class :character
#  Mode  :character   Mode  :character   Median :  1850   Mode  :character
#                                        Mean   : 12195
#                                        3rd Qu.:  9176
#                                        Max.   :171541
#   num_query_A       num_query_C      num_query_G       num_query_T
#  Min.   :  0.000   Min.   :  0.00   Min.   :  0.000   Min.   :  0.000
#  1st Qu.:  0.000   1st Qu.:  0.00   1st Qu.:  0.000   1st Qu.:  0.000
#  Median :  0.000   Median :  0.00   Median :  0.000   Median :  0.000
#  Mean   :  2.932   Mean   :  1.88   Mean   :  1.882   Mean   :  2.943
#  3rd Qu.:  2.000   3rd Qu.:  0.00   3rd Qu.:  0.000   3rd Qu.:  2.000
#  Max.   :153.000   Max.   :154.00   Max.   :154.000   Max.   :155.000
#     num_SNPs           coverage       num_discordant      num_supplementary
#  Min.   : 0.00000   Min.   :  0.000   Min.   : 0.000000   Min.   :0
#  1st Qu.: 0.00000   1st Qu.:  3.000   1st Qu.: 0.000000   1st Qu.:0
#  Median : 0.00000   Median :  5.000   Median : 0.000000   Median :0
#  Mean   : 0.01067   Mean   :  9.637   Mean   : 0.007689   Mean   :0
#  3rd Qu.: 0.00000   3rd Qu.:  9.000   3rd Qu.: 0.000000   3rd Qu.:0
#  Max.   :72.00000   Max.   :155.000   Max.   :17.000000   Max.   :0
#  num_secondary  chimeric          num_hits     query_hit_len
#  Min.   :0     Mode :logical   Min.   :1.000   Min.   :  1000
#  1st Qu.:0     FALSE:4191281   1st Qu.:1.000   1st Qu.:  2298
#  Median :0     TRUE :808714    Median :1.000   Median :  3010
#  Mean   :0                     Mean   :1.254   Mean   : 24796
#  3rd Qu.:0                     3rd Qu.:1.000   3rd Qu.: 19210
#  Max.   :0                     Max.   :4.000   Max.   :171542
#    edit_dist       edit_dist_norm      Extensive_misassembly     Rep
#  Min.   :   0.00   Min.   :0.0000000   Length:4999995        Length:4999995
#  1st Qu.:   1.00   1st Qu.:0.0001046   Class :character      Class :character
#  Median :   2.00   Median :0.0006515   Mode  :character      Mode  :character
#  Mean   :  78.11   Mean   :0.0045711
#  3rd Qu.:   5.00   3rd Qu.:0.0015209
#  Max.   :1725.00   Max.   :0.4138577

# %%
# should not have more SNPs than coverage
feats %>%
    filter(num_SNPs > coverage) %>%
    nrow %>% print
# Out:
# [1] 0

# %%
# sum(num_query_*) should equal coverage
feats %>%
    filter(num_query_A + num_query_C + num_query_G + num_query_T != coverage) %>%
    nrow %>% print
# Out:
# [1] 0

# %% [markdown]
# ## n1000_r30

# %%
feat_files = list.files(file.path(n1000_r30_dir, 'map'), 'features.tsv.gz', full.names=TRUE, recursive=TRUE)
feat_files %>% length %>% print
feat_files %>% head
# Out:
# [1] 60
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/map/1/megahit/features.tsv.gz"
# [2] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/map/1/metaspades/features.tsv.gz"
# [3] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/map/10/megahit/features.tsv.gz"
# [4] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/map/10/metaspades/features.tsv.gz"
# [5] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/map/11/megahit/features.tsv.gz"
# [6] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/train_runs//n1000_r30/map/11/metaspades/features.tsv.gz"

# %%
feats = list()
for(F in feat_files){
    cmd = glue::glue('gunzip -c {F}', F=F)
    df = fread(cmd, sep='\t') %>%
        distinct(contig, assembler, Extensive_misassembly)
    df$Rep = basename(dirname(dirname(F)))
    feats[[F]] = df
}
feats = do.call(rbind, feats)
rownames(feats) = 1:nrow(feats)
feats %>% dfhead
# Out:
# [1] 406739      4
#   contig     assembler Extensive_misassembly Rep
# 1 k141_10004 megahit                         1
# 2 k141_10007 megahit                         1
# 3 k141_1001  megahit                         1

# %%
p = feats %>%
    mutate(Extensive_misassembly = ifelse(Extensive_misassembly == '', 'None',
                                          Extensive_misassembly)) %>%
    group_by(Extensive_misassembly, assembler, Rep) %>%
    summarize(n = n()) %>%
    ungroup() %>%
    ggplot(aes(Extensive_misassembly, n, color=assembler)) +
    geom_boxplot() +
    scale_y_log10() +
    labs(x='metaQUAST extensive mis-assembly', y='Count') +
    coord_flip() +
    theme_bw() +
    theme(
        axis.text.x = element_text(angle=45, hjust=1)
    )

dims(7,4)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ### SNPs ~ coverage

# %%
# loading files; just checking first million lines (should be sufficient)
feats = list()
for(F in feat_files){
    cmd = glue::glue('gunzip -c {F} | head -n 1000000', F=F)
    df = fread(cmd, sep='\t') 
    df$Rep = basename(dirname(dirname(F)))
    feats[[F]] = df
}
feats = do.call(rbind, feats)
rownames(feats) = 1:nrow(feats)
feats %>% dfhead
# Out:
# [1] 59999940       20
#   contig     assembler position ref_base num_query_A num_query_C num_query_G
# 1 k141_10004 megahit   0        C        0           1           0
# 2 k141_10004 megahit   1        C        0           1           0
# 3 k141_10004 megahit   2        A        1           0           0
#   num_query_T num_SNPs coverage num_discordant num_supplementary num_secondary
# 1 0           0        1        0              0                 0
# 2 0           0        1        0              0                 0
# 3 0           0        1        0              0                 0
#   chimeric num_hits query_hit_len edit_dist edit_dist_norm
# 1 FALSE    1        1164          0         0
# 2 FALSE    1        1164          0         0
# 3 FALSE    1        1164          0         0
#   Extensive_misassembly Rep
# 1                       1
# 2                       1
# 3                       1

# %%
# general summary
feats %>% summary
# Out:
#     contig           assembler            position        ref_base
#  Length:59999940    Length:59999940    Min.   :     0   Length:59999940
#  Class :character   Class :character   1st Qu.:   608   Class :character
#  Mode  :character   Mode  :character   Median :  1250   Mode  :character
#                                        Mean   :  6850
#                                        3rd Qu.:  2484
#                                        Max.   :496930
#   num_query_A       num_query_C     num_query_G       num_query_T
#  Min.   :  0.000   Min.   :  0.0   Min.   :  0.000   Min.   :  0.000
#  1st Qu.:  0.000   1st Qu.:  0.0   1st Qu.:  0.000   1st Qu.:  0.000
#  Median :  0.000   Median :  0.0   Median :  0.000   Median :  0.000
#  Mean   :  1.387   Mean   :  1.2   Mean   :  1.205   Mean   :  1.385
#  3rd Qu.:  1.000   3rd Qu.:  0.0   3rd Qu.:  0.000   3rd Qu.:  1.000
#  Max.   :282.000   Max.   :281.0   Max.   :284.000   Max.   :280.000
#     num_SNPs           coverage       num_discordant     num_supplementary
#  Min.   :0.00e+00   Min.   :  0.000   Min.   : 0.00000   Min.   :0
#  1st Qu.:0.00e+00   1st Qu.:  2.000   1st Qu.: 0.00000   1st Qu.:0
#  Median :0.00e+00   Median :  4.000   Median : 0.00000   Median :0
#  Mean   :6.74e-03   Mean   :  5.178   Mean   : 0.00443   Mean   :0
#  3rd Qu.:0.00e+00   3rd Qu.:  6.000   3rd Qu.: 0.00000   3rd Qu.:0
#  Max.   :1.88e+02   Max.   :284.000   Max.   :53.00000   Max.   :0
#  num_secondary  chimeric           num_hits      query_hit_len
#  Min.   :0     Mode :logical    Min.   : 1.000   Min.   :   857
#  1st Qu.:0     FALSE:49786981   1st Qu.: 1.000   1st Qu.:  1831
#  Median :0     TRUE :10212959   Median : 1.000   Median :  2576
#  Mean   :0                      Mean   : 1.374   Mean   : 14399
#  3rd Qu.:0                      3rd Qu.: 1.000   3rd Qu.:  5676
#  Max.   :0                      Max.   :12.000   Max.   :520935
#    edit_dist      edit_dist_norm      Extensive_misassembly     Rep
#  Min.   :   0.0   Min.   :0.0000000   Length:59999940       Length:59999940
#  1st Qu.:   1.0   1st Qu.:0.0003113   Class :character      Class :character
#  Median :   2.0   Median :0.0008326   Mode  :character      Mode  :character
#  Mean   : 169.8   Mean   :0.0093380
#  3rd Qu.:   5.0   3rd Qu.:0.0019108
#  Max.   :7163.0   Max.   :0.4835165

# %%
# should not have more SNPs than coverage
feats %>%
    filter(num_SNPs > coverage) %>%
    nrow %>% print
# Out:
# [1] 0

# %%
# sum(num_query_*) should equal coverage
feats %>%
    filter(num_query_A + num_query_C + num_query_G + num_query_T != coverage) %>%
    nrow %>% print
# Out:
# [1] 0

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.1 LTS
#
# Matrix products: default
# BLAS: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRblas.so
# LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRlapack.so
#
# locale:
# [1] en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] data.table_1.11.4 bindrcpp_0.2.2    ggplot2_3.0.0     tidyr_0.8.1
# [5] dplyr_0.7.6
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.17     pillar_1.2.2     compiler_3.4.1   plyr_1.8.4
#  [5] bindr_0.1.1      base64enc_0.1-3  tools_3.4.1      digest_0.6.15
#  [9] uuid_0.1-2       jsonlite_1.5     evaluate_0.10.1  tibble_1.4.2
# [13] gtable_0.2.0     pkgconfig_2.0.1  rlang_0.2.1      IRdisplay_0.4.4
# [17] IRkernel_0.8.12  repr_0.15.0      withr_2.1.1      stringr_1.3.1
# [21] grid_3.4.1       tidyselect_0.2.4 glue_1.3.0       R6_2.2.2
# [25] pbdZMQ_0.3-2     purrr_0.2.4      magrittr_1.5     scales_0.5.0
# [29] htmltools_0.3.6  assertthat_0.2.0 colorspace_1.3-2 labeling_0.3
# [33] stringi_1.2.3    lazyeval_0.2.1   munsell_0.5.0    crayon_1.3.4
