# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Running-ALE" data-toc-modified-id="Running-ALE-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Running ALE</a></span></li><li><span><a href="#Summarizing-results" data-toc-modified-id="Summarizing-results-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Summarizing results</a></span><ul class="toc-item"><li><span><a href="#Writing-combined-ALE-results" data-toc-modified-id="Writing-combined-ALE-results-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Writing combined ALE results</a></span></li></ul></li><li><span><a href="#---WAITING---" data-toc-modified-id="---WAITING----7"><span class="toc-item-num">7&nbsp;&nbsp;</span>-- WAITING --</a></span></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * run ALE on simulated test dataset for DeepMAsED
#   * the ground truth results can be used for selecting cutoffs for ALE and assessing accuracy

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE/'

# MAGs for genome analysis
asmbl_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly/'

# bam file dir (mapping of metagenome reads to corresponding MAGs)
map_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map/'

# ALE executable
ALE_exe = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/bin/ALE/src/ALE'

# params
conda_env = 'base'
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(doParallel)

library(future)
library(future.batchtools)
library(future.apply)
options(future.wait.interval = 2.0)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# Loading required package: foreach
# Loading required package: iterators
# Loading required package: parallel
#
# Attaching package: ‘future.apply’
#
# The following object is masked from ‘package:future’:
#
#     future_lapply

# %% [markdown]
# # Load

# %%
# adding bam files
fasta_files = list.files(asmbl_dir, '*.fasta$', recursive=TRUE, full.names=TRUE)
fasta_files = data.frame(Assembler = fasta_files %>% dirname %>% basename,
                         Rep = fasta_files %>% dirname %>% dirname %>% basename,
                         Fasta = fasta_files)

fasta_files %>% nrow %>% print
fasta_files %>% head(n=3)
# Out:
# [1] 60
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    10
#   Fasta
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/megahit/contigs_filtered.fasta
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/metaspades/contigs_filtered.fasta
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//10/megahit/contigs_filtered.fasta

# %%
# adding bam files
bam_files = list.files(map_dir, '*.bam$', recursive=TRUE, full.names=TRUE)
bam_files = data.frame(Assembler = bam_files %>% basename %>% gsub('\\.bam$', '', .),
                       Rep = bam_files %>% dirname %>% basename,
                       Bam = bam_files)

bam_files %>% nrow %>% print
bam_files %>% head(n=3)
# Out:
# [1] 58
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    10
#   Bam
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/megahit.bam
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/metaspades.bam
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//10/megahit.bam

# %%
# joining
MAGs = fasta_files %>%
    inner_join(bam_files, c('Assembler', 'Rep'))
MAGs %>% nrow %>% print
MAGs %>% head(n=3)
# Out:
# Warning message:
# “Column `Rep` joining factors with different levels, coercing to character vector”
# [1] 58
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    10
#   Fasta
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/megahit/contigs_filtered.fasta
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/metaspades/contigs_filtered.fasta
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//10/megahit/contigs_filtered.fasta
#   Bam
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/megahit.bam
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/metaspades.bam
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//10/megahit.bam

# %%
# ALE output file name
MAGs = MAGs %>%
    mutate(ALE = mapply(function(A, R) file.path(work_dir, R, paste0(A, '.txt')),
                        A=Assembler, R=Rep))
                        
MAGs %>% head(n=3)
# Out:
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    10
#   Fasta
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/megahit/contigs_filtered.fasta
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/metaspades/contigs_filtered.fasta
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//10/megahit/contigs_filtered.fasta
#   Bam
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/megahit.bam
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/metaspades.bam
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//10/megahit.bam
#   ALE
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/megahit.txt
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/metaspades.txt
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/megahit.txt

# %%
# making output directories
ret = MAGs$ALE %>% 
    dirname() %>%
    unique() %>%
    sapply(., function(x) dir.create(x, showWarnings=FALSE))

# %% [markdown]
# # Running ALE

# %%
# cluster resources
resources = list(h_rt = '00:59:00',
                 h_vmem = '8G',
                 threads = '1',
                 conda.env = 'py3_physeq')     # conda env with batchtools installed
plan(batchtools_sge, resources=resources, workers=30)

# %%
# creating commands for calling ALE 
ALE_params = function(x, exe){
    cmd = '{exe} {bam} {fasta} {outfile}'
    cmd = glue::glue(cmd, exe=exe, bam=x[['Bam']], fasta=x[['Fasta']], outfile=x[['ALE']])
    return(cmd)
}

ALE_cmds = apply(MAGs, 1, ALE_params, exe=ALE_exe) %>%
    as.list

ALE_cmds %>% length %>% print
ALE_cmds[[1]]
# Out:
# [1] 58
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/bin/ALE/src/ALE /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/megahit.bam /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/megahit/contigs_filtered.fasta /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/megahit.txt"

# %%
# general bash job function
bash_job = function(cmd, conda_env, stdout=TRUE, stderr=FALSE){
    # cmd : string; commandline job (eg., 'ls -thlc')
    # conda_env : string; conda environment name
    cmd = sprintf('. ~/.bashrc; conda activate %s; %s', conda_env, cmd)
    cmd = sprintf('-c "%s"', cmd)
    system2('bash', cmd, stdout=stdout, stderr=stderr)
}

# %%
# apply function on cluster
job_ret = future_lapply(ALE_cmds, FUN = function(x) bash_job(x, conda_env=conda_env))
job_ret
# Out:
# [[1]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.723707 from 1212220 mapped reads"
#  [9] "Found FR sample insert length std to be 9.925705"
# [10] "There were 1260475 total reads, 1260475 paired (1257682 properly mated), 2073 proper singles, 720 improper reads (690 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1257682 reads, 1257682 mapped, 0 unmapped, 1257681 placed, 1 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 14 reads, 14 mapped, 0 unmapped, 14 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 14 reads, 14 mapped, 0 unmapped, 14 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 690 reads, 690 mapped, 0 unmapped, 690 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2043 reads, 2043 mapped, 0 unmapped, 2043 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 30 reads, 30 mapped, 0 unmapped, 30 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1260475"
# [29] "Total placed reads: 1260474"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 1"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 17197"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1203.800955"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -22697096.942980"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/megahit.txt"
# [45] "Closing input file"
#
# [[2]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//1/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//1/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.732010 from 1201202 mapped reads"
#  [9] "Found FR sample insert length std to be 9.931224"
# [10] "There were 1249353 total reads, 1249353 paired (1246230 properly mated), 2167 proper singles, 956 improper reads (912 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1246230 reads, 1246230 mapped, 0 unmapped, 1246230 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 32 reads, 32 mapped, 0 unmapped, 32 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 12 reads, 12 mapped, 0 unmapped, 12 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 912 reads, 912 mapped, 0 unmapped, 912 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2133 reads, 2133 mapped, 0 unmapped, 2133 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 34 reads, 34 mapped, 0 unmapped, 34 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1249353"
# [29] "Total placed reads: 1249353"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 11647"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1221.800000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -22172524.551273"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/metaspades.txt"
# [45] "Closing input file"
#
# [[3]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//10/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//10/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.735681 from 1270902 mapped reads"
#  [9] "Found FR sample insert length std to be 9.930199"
# [10] "There were 1321605 total reads, 1321605 paired (1318686 properly mated), 1987 proper singles, 932 improper reads (880 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1318686 reads, 1318686 mapped, 0 unmapped, 1318686 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 16 reads, 16 mapped, 0 unmapped, 16 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 22 reads, 22 mapped, 0 unmapped, 22 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 14 reads, 14 mapped, 0 unmapped, 14 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 880 reads, 880 mapped, 0 unmapped, 880 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 1973 reads, 1973 mapped, 0 unmapped, 1973 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 14 reads, 14 mapped, 0 unmapped, 14 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1321605"
# [29] "Total placed reads: 1321605"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 15898"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1278.400000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -19122156.831738"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/megahit.txt"
# [45] "Closing input file"
#
# [[4]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//10/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//10/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.730003 from 1262138 mapped reads"
#  [9] "Found FR sample insert length std to be 9.927099"
# [10] "There were 1312751 total reads, 1312751 paired (1309554 properly mated), 2309 proper singles, 888 improper reads (836 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1309554 reads, 1309554 mapped, 0 unmapped, 1309553 placed, 1 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 34 reads, 34 mapped, 0 unmapped, 34 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 16 reads, 16 mapped, 0 unmapped, 16 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 836 reads, 836 mapped, 0 unmapped, 836 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2289 reads, 2289 mapped, 0 unmapped, 2289 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 20 reads, 20 mapped, 0 unmapped, 20 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1312751"
# [29] "Total placed reads: 1312750"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 1"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 9767"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1267.800966"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -18755636.338068"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/metaspades.txt"
# [45] "Closing input file"
#
# [[5]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//11/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//11/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.769628 from 1229856 mapped reads"
#  [9] "Found FR sample insert length std to be 9.945784"
# [10] "There were 1278594 total reads, 1278594 paired (1276032 properly mated), 1706 proper singles, 856 improper reads (778 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1276032 reads, 1276032 mapped, 0 unmapped, 1276031 placed, 1 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 52 reads, 52 mapped, 0 unmapped, 52 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 24 reads, 24 mapped, 0 unmapped, 24 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 778 reads, 778 mapped, 0 unmapped, 778 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 1674 reads, 1674 mapped, 0 unmapped, 1674 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 32 reads, 32 mapped, 0 unmapped, 32 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1278594"
# [29] "Total placed reads: 1278593"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 1"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 13435"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1076.300842"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -12552137.564932"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/megahit.txt"
# [45] "Closing input file"
#
# [[6]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//11/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//11/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.750257 from 1222898 mapped reads"
#  [9] "Found FR sample insert length std to be 9.940087"
# [10] "There were 1271913 total reads, 1271913 paired (1268674 properly mated), 1953 proper singles, 1286 improper reads (1220 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1268674 reads, 1268674 mapped, 0 unmapped, 1268674 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 40 reads, 40 mapped, 0 unmapped, 39 placed, 1 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 26 reads, 26 mapped, 0 unmapped, 26 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 1220 reads, 1220 mapped, 0 unmapped, 1220 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 1909 reads, 1909 mapped, 0 unmapped, 1909 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 44 reads, 44 mapped, 0 unmapped, 44 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1271913"
# [29] "Total placed reads: 1271912"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 1"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 12144"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1243.700978"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -12235260.934613"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/metaspades.txt"
# [45] "Closing input file"
#
# [[7]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//12/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//12/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//12/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.769835 from 1441024 mapped reads"
#  [9] "Found FR sample insert length std to be 9.947323"
# [10] "There were 1498680 total reads, 1498680 paired (1495500 properly mated), 2118 proper singles, 1062 improper reads (1004 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//12/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1495500 reads, 1495500 mapped, 0 unmapped, 1495495 placed, 5 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 38 reads, 38 mapped, 0 unmapped, 38 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 20 reads, 20 mapped, 0 unmapped, 20 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 1004 reads, 1004 mapped, 0 unmapped, 1004 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2072 reads, 2072 mapped, 0 unmapped, 2072 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 46 reads, 46 mapped, 0 unmapped, 46 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1498680"
# ...
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 19772"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1166.901075"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -26982645.501738"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//8/metaspades.txt"
# [45] "Closing input file"
#
# [[57]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//9/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//9/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//9/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.733004 from 1150100 mapped reads"
#  [9] "Found FR sample insert length std to be 9.920223"
# [10] "There were 1195606 total reads, 1195606 paired (1193070 properly mated), 2166 proper singles, 370 improper reads (354 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//9/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1193070 reads, 1193070 mapped, 0 unmapped, 1193070 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 10 reads, 10 mapped, 0 unmapped, 10 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 4 reads, 4 mapped, 0 unmapped, 4 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 354 reads, 354 mapped, 0 unmapped, 354 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2160 reads, 2160 mapped, 0 unmapped, 2160 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1195606"
# [29] "Total placed reads: 1195606"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 22245"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1177.000000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -19579897.957545"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//9/megahit.txt"
# [45] "Closing input file"
#
# [[58]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/map//9/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/assembly//9/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//9/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.713040 from 1139810 mapped reads"
#  [9] "Found FR sample insert length std to be 9.913492"
# [10] "There were 1185114 total reads, 1185114 paired (1182324 properly mated), 2034 proper singles, 756 improper reads (748 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//9/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1182324 reads, 1182324 mapped, 0 unmapped, 1182324 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 748 reads, 748 mapped, 0 unmapped, 748 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2034 reads, 2034 mapped, 0 unmapped, 2034 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1185114"
# [29] "Total placed reads: 1185114"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 14551"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 864.600000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -18995038.934677"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//9/metaspades.txt"
# [45] "Closing input file"

# %% [markdown]
# # Summarizing results

# %%
ALE_res_files = list.files(work_dir, '*.txt$', recursive=TRUE, full.names=TRUE)
ALE_res_files %>% length %>% print
ALE_res_files %>% head
# Out:
# [1] 58
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/megahit.txt"
# [2] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//1/metaspades.txt"
# [3] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/megahit.txt"
# [4] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//10/metaspades.txt"
# [5] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/megahit.txt"
# [6] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//11/metaspades.txt"

# %%
read_ALE_files = function(in_file){
    # input command
    cmd = 'egrep -v "^#" {in_file}'
    cmd = glue::glue(cmd, in_file=in_file)
    # reading in table
    df = fread(cmd, sep=' ', header=FALSE)
    # formatting
    colnames(df) = c('contig', 'position', 'depth', 
                     'ln__depthLike', 'ln__placeLike', 
                     'ln__insertLike', 'ln__kmerLike')
    df$Assembler = in_file %>% basename %>% gsub('\\.txt$', '', .)
    df$Rep = in_file %>% dirname %>% basename
    return(df)
}

# %%
doParallel::registerDoParallel(threads)
ALE_res = plyr::llply(as.list(ALE_res_files), read_ALE_files, .parallel=TRUE) %>%
    do.call(rbind, .)

ALE_res %>% nrow %>% print
ALE_res %>% head(n=3)
# Out:
# [1] 1641203714
#   contig position depth ln__depthLike ln__placeLike ln__insertLike ln__kmerLike
# 1 0      0        1     -2.601        -0.003        0.044          0.001
# 2 0      1        1     -2.601        -0.003        0.044          0.076
# 3 0      2        1     -2.601        -0.003        0.044          0.246
#   Assembler Rep
# 1 megahit   1
# 2 megahit   1
# 3 megahit   1

# %% [markdown]
# ## Writing combined ALE results

# %%
out_file = file.path(work_dir, 'ALE_results.tsv')
ALE_res %>%
    write.table(file=out_file, sep='\t', quote=FALSE, row.names=FALSE)
cat('File written:', out_file, '\n')
# Out:
# File written: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r25/ALE//ALE_results.tsv

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.1 LTS
#
# Matrix products: default
# BLAS: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRblas.so
# LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRlapack.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] bindrcpp_0.2.2          future.apply_1.0.0      future.batchtools_0.7.1
#  [4] future_1.9.0            doParallel_1.0.11       iterators_1.0.10
#  [7] foreach_1.4.4           data.table_1.11.4       ggplot2_3.0.0
# [10] tidyr_0.8.1             dplyr_0.7.6
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-2      progress_1.2.0    tidyselect_0.2.4  repr_0.15.0
#  [5] purrr_0.2.4       listenv_0.7.0     colorspace_1.3-2  htmltools_0.3.6
#  [9] base64enc_0.1-3   rlang_0.2.1       pillar_1.2.2      glue_1.3.0
# [13] withr_2.1.1       rappdirs_0.3.1    uuid_0.1-2        bindr_0.1.1
# [17] plyr_1.8.4        stringr_1.3.1     munsell_0.5.0     gtable_0.2.0
# [21] codetools_0.2-15  evaluate_0.10.1   batchtools_0.9.11 IRdisplay_0.4.4
# [25] Rcpp_0.12.17      scales_0.5.0      backports_1.1.2   checkmate_1.8.5
# [29] IRkernel_0.8.12   jsonlite_1.5      fs_1.2.6          brew_1.0-6
# [33] hms_0.4.2         digest_0.6.15     stringi_1.2.3     grid_3.4.1
# [37] tools_3.4.1       magrittr_1.5      base64url_1.4     lazyeval_0.2.1
# [41] tibble_1.4.2      crayon_1.3.4      pkgconfig_2.0.1   prettyunits_1.0.2
# [45] assertthat_0.2.0  R6_2.2.2          globals_0.12.2    compiler_3.4.1
