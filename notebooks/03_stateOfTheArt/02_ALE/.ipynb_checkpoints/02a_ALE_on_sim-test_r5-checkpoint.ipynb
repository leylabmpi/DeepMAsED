# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Running-ALE" data-toc-modified-id="Running-ALE-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Running ALE</a></span></li><li><span><a href="#Summarizing-results" data-toc-modified-id="Summarizing-results-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Summarizing results</a></span><ul class="toc-item"><li><span><a href="#Writing-combined-ALE-results" data-toc-modified-id="Writing-combined-ALE-results-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Writing combined ALE results</a></span></li></ul></li><li><span><a href="#---WAITING---" data-toc-modified-id="---WAITING----7"><span class="toc-item-num">7&nbsp;&nbsp;</span>-- WAITING --</a></span></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * run ALE on simulated test dataset for DeepMAsED
#   * the ground truth results can be used for selecting cutoffs for ALE and assessing accuracy

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE/'

# MAGs for genome analysis
asmbl_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly/'

# bam file dir (mapping of metagenome reads to corresponding MAGs)
map_dir = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map/'

# ALE executable
ALE_exe = '/ebio/abt3_projects/databases_no-backup/DeepMAsED/bin/ALE/src/ALE'

# params
conda_env = 'base'
threads = 12

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)
library(doParallel)

library(future)
library(future.batchtools)
library(future.apply)
options(future.wait.interval = 2.0)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching package: ‘data.table’
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
# Loading required package: foreach
# Loading required package: iterators
# Loading required package: parallel
#
# Attaching package: ‘future.apply’
#
# The following object is masked from ‘package:future’:
#
#     future_lapply

# %% [markdown]
# # Load

# %%
# adding bam files
fasta_files = list.files(asmbl_dir, '*.fasta$', recursive=TRUE, full.names=TRUE)
fasta_files = data.frame(Assembler = fasta_files %>% dirname %>% basename,
                         Rep = fasta_files %>% dirname %>% dirname %>% basename,
                         Fasta = fasta_files)

fasta_files %>% nrow %>% print
fasta_files %>% head(n=3)
# Out:
# [1] 10
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    2
#   Fasta
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/megahit/contigs_filtered.fasta
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/metaspades/contigs_filtered.fasta
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//2/megahit/contigs_filtered.fasta

# %%
# adding bam files
bam_files = list.files(map_dir, '*.bam$', recursive=TRUE, full.names=TRUE)
bam_files = data.frame(Assembler = bam_files %>% basename %>% gsub('\\.bam$', '', .),
                       Rep = bam_files %>% dirname %>% basename,
                       Bam = bam_files)

bam_files %>% nrow %>% print
bam_files %>% head(n=3)
# Out:
# [1] 10
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    2
#   Bam
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/megahit.bam
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/metaspades.bam
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//2/megahit.bam

# %%
# joining
MAGs = fasta_files %>%
    inner_join(bam_files, c('Assembler', 'Rep'))
MAGs %>% nrow %>% print
MAGs %>% head(n=3)
# Out:
# [1] 10
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    2
#   Fasta
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/megahit/contigs_filtered.fasta
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/metaspades/contigs_filtered.fasta
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//2/megahit/contigs_filtered.fasta
#   Bam
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/megahit.bam
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/metaspades.bam
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//2/megahit.bam

# %%
# ALE output file name
MAGs = MAGs %>%
    mutate(ALE = mapply(function(A, R) file.path(work_dir, R, paste0(A, '.txt')),
                        A=Assembler, R=Rep))
                        
MAGs %>% head(n=3)
# Out:
#   Assembler  Rep
# 1 megahit    1
# 2 metaspades 1
# 3 megahit    2
#   Fasta
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/megahit/contigs_filtered.fasta
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/metaspades/contigs_filtered.fasta
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//2/megahit/contigs_filtered.fasta
#   Bam
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/megahit.bam
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/metaspades.bam
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//2/megahit.bam
#   ALE
# 1 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/megahit.txt
# 2 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/metaspades.txt
# 3 /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/megahit.txt

# %%
# making output directories
ret = MAGs$ALE %>% 
    dirname() %>%
    unique() %>%
    sapply(., function(x) dir.create(x, showWarnings=FALSE))

# %% [markdown]
# # Running ALE

# %%
# cluster resources
resources = list(h_rt = '00:59:00',
                 h_vmem = '8G',
                 threads = '1',
                 conda.env = 'py3_physeq')     # conda env with batchtools installed
plan(batchtools_sge, resources=resources, workers=30)

# %%
# creating commands for calling ALE 
ALE_params = function(x, exe){
    cmd = '{exe} {bam} {fasta} {outfile}'
    cmd = glue::glue(cmd, exe=exe, bam=x[['Bam']], fasta=x[['Fasta']], outfile=x[['ALE']])
    return(cmd)
}

ALE_cmds = apply(MAGs, 1, ALE_params, exe=ALE_exe) %>%
    as.list

ALE_cmds %>% length %>% print
ALE_cmds[[1]]
# Out:
# [1] 10
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/bin/ALE/src/ALE /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/megahit.bam /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/megahit/contigs_filtered.fasta /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/megahit.txt"

# %%
# general bash job function
bash_job = function(cmd, conda_env, stdout=TRUE, stderr=FALSE){
    # cmd : string; commandline job (eg., 'ls -thlc')
    # conda_env : string; conda environment name
    cmd = sprintf('. ~/.bashrc; conda activate %s; %s', conda_env, cmd)
    cmd = sprintf('-c "%s"', cmd)
    system2('bash', cmd, stdout=stdout, stderr=stderr)
}

# %%
# apply function on cluster
job_ret = future_lapply(ALE_cmds, FUN = function(x) bash_job(x, conda_env=conda_env))
job_ret
# Out:
# [[1]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.728772 from 1090912 mapped reads"
#  [9] "Found FR sample insert length std to be 9.916796"
# [10] "There were 1135136 total reads, 1135136 paired (1131604 properly mated), 2300 proper singles, 1232 improper reads (1190 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1131604 reads, 1131604 mapped, 0 unmapped, 1131604 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 34 reads, 34 mapped, 0 unmapped, 34 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 1190 reads, 1190 mapped, 0 unmapped, 1190 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2278 reads, 2278 mapped, 0 unmapped, 2278 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 22 reads, 22 mapped, 0 unmapped, 22 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1135136"
# [29] "Total placed reads: 1135136"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 19449"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1725.100000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -21341424.829069"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/megahit.txt"
# [45] "Closing input file"
#
# [[2]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//1/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//1/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.732094 from 1076982 mapped reads"
#  [9] "Found FR sample insert length std to be 9.919110"
# [10] "There were 1121157 total reads, 1121157 paired (1117228 properly mated), 2707 proper singles, 1222 improper reads (1182 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1117228 reads, 1117228 mapped, 0 unmapped, 1117228 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 34 reads, 34 mapped, 0 unmapped, 34 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 1182 reads, 1182 mapped, 0 unmapped, 1182 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2705 reads, 2705 mapped, 0 unmapped, 2705 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1121157"
# [29] "Total placed reads: 1121157"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 14176"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1816.600000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -20576586.864308"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/metaspades.txt"
# [45] "Closing input file"
#
# [[3]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//2/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//2/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Found FR sample avg insert length to be 253.733571 from 928224 mapped reads"
#  [8] "Found FR sample insert length std to be 9.907996"
#  [9] "There were 966493 total reads, 966493 paired (962814 properly mated), 3041 proper singles, 638 improper reads (592 chimeric). (0 reads were unmapped)"
# [10] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/megahit.txt.param"
# [11] "Computing read placements and depths"
# [12] "FR orientation with 962814 reads, 962814 mapped, 0 unmapped, 962814 placed, 0 mappedButNotPlaced"
# [13] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [14] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [15] "NOT_PROPER_FR orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [16] "NOT_PROPER_RF orientation with 40 reads, 40 mapped, 0 unmapped, 40 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [18] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [19] "CHIMER orientation with 592 reads, 592 mapped, 0 unmapped, 592 placed, 0 mappedButNotPlaced"
# [20] "SINGLE_UNMAPPED_MATE orientation with 3031 reads, 3031 mapped, 0 unmapped, 3031 placed, 0 mappedButNotPlaced"
# [21] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [22] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [23] "SINGLE_READ orientation with 10 reads, 10 mapped, 0 unmapped, 10 placed, 0 mappedButNotPlaced"
# [24] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [26] "Total mapped reads: 966493"
# [27] "Total placed reads: 966493"
# [28] "Total unmapped reads: 0"
# [29] "Total unplaced reads: 0"
# [30] "Computing k-mer statistics..."
# [31] "Done computing k-mer statistics."
# [32] "Computing depth statistics..."
# [33] "bases with no GC depth correction metric (small contigs): 0"
# [34] "unmappable bases: 0 across 0 different regions"
# [35] "bases with 0 coverage: 28327"
# [36] "Done computing depth statistics."
# [37] "Computing statistics on expected missing..."
# [38] "Expected extra length: 1641.300000"
# [39] "Done computing statistics on expected missing."
# [40] "Set minLogLike to: -120.0"
# [41] "Total ALE Score: -25478193.858699"
# [42] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/megahit.txt"
# [43] "Closing input file"
#
# [[4]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//2/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//2/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Found FR sample avg insert length to be 253.703599 from 913356 mapped reads"
#  [8] "Found FR sample insert length std to be 9.897229"
#  [9] "There were 951219 total reads, 951219 paired (947314 properly mated), 3097 proper singles, 808 improper reads (760 chimeric). (0 reads were unmapped)"
# [10] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/metaspades.txt.param"
# [11] "Computing read placements and depths"
# [12] "FR orientation with 947314 reads, 947314 mapped, 0 unmapped, 947314 placed, 0 mappedButNotPlaced"
# [13] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [14] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [15] "NOT_PROPER_FR orientation with 30 reads, 30 mapped, 0 unmapped, 29 placed, 1 mappedButNotPlaced"
# [16] "NOT_PROPER_RF orientation with 18 reads, 18 mapped, 0 unmapped, 18 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [18] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [19] "CHIMER orientation with 760 reads, 760 mapped, 0 unmapped, 760 placed, 0 mappedButNotPlaced"
# [20] "SINGLE_UNMAPPED_MATE orientation with 3093 reads, 3093 mapped, 0 unmapped, 3093 placed, 0 mappedButNotPlaced"
# [21] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [22] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [23] "SINGLE_READ orientation with 4 reads, 4 mapped, 0 unmapped, 4 placed, 0 mappedButNotPlaced"
# [24] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [26] "Total mapped reads: 951219"
# [27] "Total placed reads: 951218"
# [28] "Total unmapped reads: 0"
# [29] "Total unplaced reads: 1"
# [30] "Computing k-mer statistics..."
# [31] "Done computing k-mer statistics."
# [32] "Computing depth statistics..."
# [33] "bases with no GC depth correction metric (small contigs): 0"
# [34] "unmappable bases: 0 across 0 different regions"
# [35] "bases with 0 coverage: 19554"
# [36] "Done computing depth statistics."
# [37] "Computing statistics on expected missing..."
# [38] "Expected extra length: 1253.001317"
# [39] "Done computing statistics on expected missing."
# [40] "Set minLogLike to: -120.0"
# [41] "Total ALE Score: -24557003.672984"
# [42] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/metaspades.txt"
# [43] "Closing input file"
#
# [[5]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//3/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//3/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.723209 from 1264320 mapped reads"
#  [9] "Found FR sample insert length std to be 9.916738"
# [10] "There were 1314913 total reads, 1314913 paired (1311512 properly mated), 2789 proper singles, 612 improper reads (552 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1311512 reads, 1311512 mapped, 0 unmapped, 1311512 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 32 reads, 32 mapped, 0 unmapped, 32 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 22 reads, 22 mapped, 0 unmapped, 22 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 552 reads, 552 mapped, 0 unmapped, 552 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2769 reads, 2769 mapped, 0 unmapped, 2769 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 20 reads, 20 mapped, 0 unmapped, 20 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1314913"
# [29] "Total placed reads: 1314913"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 33103"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1860.700000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -23376993.706206"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/megahit.txt"
# [45] "Closing input file"
#
# [[6]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//3/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//3/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.700152 from 1250640 mapped reads"
#  [9] "Found FR sample insert length std to be 9.905588"
# [10] "There were 1300973 total reads, 1300973 paired (1297176 properly mated), 2867 proper singles, 930 improper reads (836 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1297176 reads, 1297176 mapped, 0 unmapped, 1297176 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 24 reads, 24 mapped, 0 unmapped, 24 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 68 reads, 68 mapped, 0 unmapped, 68 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 836 reads, 836 mapped, 0 unmapped, 836 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2857 reads, 2857 mapped, 0 unmapped, 2857 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 10 reads, 10 mapped, 0 unmapped, 10 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1300973"
# [29] "Total placed reads: 1300973"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 19826"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1405.300000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -22645031.366919"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/metaspades.txt"
# [45] "Closing input file"
#
# [[7]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//4/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//4/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//4/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.733832 from 1154228 mapped reads"
#  [9] "Found FR sample insert length std to be 9.930490"
# [10] "There were 1200825 total reads, 1200825 paired (1197536 properly mated), 2001 proper singles, 1288 improper reads (1204 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//4/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1197536 reads, 1197536 mapped, 0 unmapped, 1197536 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 50 reads, 50 mapped, 0 unmapped, 50 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 32 reads, 32 mapped, 0 unmapped, 32 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 2 reads, 2 mapped, 0 unmapped, 2 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 1204 reads, 1204 mapped, 0 unmapped, 1204 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 1985 reads, 1985 mapped, 0 unmapped, 1985 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 16 reads, 16 mapped, 0 unmapped, 16 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1200825"
# [29] "Total placed reads: 1200825"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# ...
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 11768"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1899.400000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -14888272.486862"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//4/metaspades.txt"
# [45] "Closing input file"
#
# [[9]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//5/megahit.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//5/megahit/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//5/megahit.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.737512 from 1062958 mapped reads"
#  [9] "Found FR sample insert length std to be 9.924341"
# [10] "There were 1105900 total reads, 1105900 paired (1102664 properly mated), 2398 proper singles, 838 improper reads (782 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//5/megahit.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1102664 reads, 1102664 mapped, 0 unmapped, 1102664 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 36 reads, 36 mapped, 0 unmapped, 36 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 16 reads, 16 mapped, 0 unmapped, 16 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 4 reads, 4 mapped, 0 unmapped, 4 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 782 reads, 782 mapped, 0 unmapped, 782 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2392 reads, 2392 mapped, 0 unmapped, 2392 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 6 reads, 6 mapped, 0 unmapped, 6 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1105900"
# [29] "Total placed reads: 1105900"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 15980"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1359.800000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -25110464.260699"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//5/megahit.txt"
# [45] "Closing input file"
#
# [[10]]
#  [1] "BAM file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/map//5/metaspades.bam"
#  [2] "Assembly fasta file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/assembly//5/metaspades/contigs_filtered.fasta"
#  [3] "ALE Output file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//5/metaspades.txt"
#  [4] "Reading in assembly..."
#  [5] "Reading in the map and computing statistics..."
#  [6] "Insert length and std not given, will be calculated from input map."
#  [7] "Read 1000000 reads..."
#  [8] "Found FR sample avg insert length to be 253.753972 from 1049684 mapped reads"
#  [9] "Found FR sample insert length std to be 9.931368"
# [10] "There were 1092573 total reads, 1092573 paired (1089006 properly mated), 2821 proper singles, 746 improper reads (694 chimeric). (0 reads were unmapped)"
# [11] "Saved library parameters to /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//5/metaspades.txt.param"
# [12] "Computing read placements and depths"
# [13] "Read 1000000 reads..."
# [14] "FR orientation with 1089006 reads, 1089006 mapped, 0 unmapped, 1089006 placed, 0 mappedButNotPlaced"
# [15] "RF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [16] "FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [17] "NOT_PROPER_FR orientation with 34 reads, 34 mapped, 0 unmapped, 34 placed, 0 mappedButNotPlaced"
# [18] "NOT_PROPER_RF orientation with 18 reads, 18 mapped, 0 unmapped, 18 placed, 0 mappedButNotPlaced"
# [19] "NOT_PROPER_FF orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [20] "UNMAPPED_PAIR orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [21] "CHIMER orientation with 694 reads, 694 mapped, 0 unmapped, 694 placed, 0 mappedButNotPlaced"
# [22] "SINGLE_UNMAPPED_MATE orientation with 2813 reads, 2813 mapped, 0 unmapped, 2813 placed, 0 mappedButNotPlaced"
# [23] "UNMAPPED_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [24] "HALF_VALID_MATE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [25] "SINGLE_READ orientation with 8 reads, 8 mapped, 0 unmapped, 8 placed, 0 mappedButNotPlaced"
# [26] "UNMAPPED_SINGLE orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [27] "NO_READS orientation with 0 reads, 0 mapped, 0 unmapped, 0 placed, 0 mappedButNotPlaced"
# [28] "Total mapped reads: 1092573"
# [29] "Total placed reads: 1092573"
# [30] "Total unmapped reads: 0"
# [31] "Total unplaced reads: 0"
# [32] "Computing k-mer statistics..."
# [33] "Done computing k-mer statistics."
# [34] "Computing depth statistics..."
# [35] "bases with no GC depth correction metric (small contigs): 0"
# [36] "unmappable bases: 0 across 0 different regions"
# [37] "bases with 0 coverage: 10146"
# [38] "Done computing depth statistics."
# [39] "Computing statistics on expected missing..."
# [40] "Expected extra length: 1370.700000"
# [41] "Done computing statistics on expected missing."
# [42] "Set minLogLike to: -120.0"
# [43] "Total ALE Score: -24422782.140910"
# [44] "Output is in file: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//5/metaspades.txt"
# [45] "Closing input file"

# %% [markdown]
# # Summarizing results

# %%
ALE_res_files = list.files(work_dir, '*.txt$', recursive=TRUE, full.names=TRUE)
ALE_res_files %>% length %>% print
ALE_res_files %>% head
# Out:
# [1] 10
# [1] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/megahit.txt"
# [2] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//1/metaspades.txt"
# [3] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/megahit.txt"
# [4] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//2/metaspades.txt"
# [5] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/megahit.txt"
# [6] "/ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//3/metaspades.txt"

# %%
read_ALE_files = function(in_file){
    # input command
    cmd = 'egrep -v "^#" {in_file}'
    cmd = glue::glue(cmd, in_file=in_file)
    # reading in table
    df = fread(cmd, sep=' ', header=FALSE)
    # formatting
    colnames(df) = c('contig', 'position', 'depth', 
                     'ln__depthLike', 'ln__placeLike', 
                     'ln__insertLike', 'ln__kmerLike')
    df$Assembler = in_file %>% basename %>% gsub('\\.txt$', '', .)
    df$Rep = in_file %>% dirname %>% basename
    return(df)
}

# %%
doParallel::registerDoParallel(threads)
ALE_res = plyr::llply(as.list(ALE_res_files), read_ALE_files, .parallel=TRUE) %>%
    do.call(rbind, .)

ALE_res %>% nrow %>% print
ALE_res %>% head(n=3)
# Out:
# [1] 295103567
#   contig position depth ln__depthLike ln__placeLike ln__insertLike ln__kmerLike
# 1 0      0        1     -2.601        -0.004        -1.169         -0.020
# 2 0      1        1     -2.601        -0.005        -1.169         -0.059
# 3 0      2        1     -2.601        -0.004        -1.169         -0.062
#   Assembler Rep
# 1 megahit   1
# 2 megahit   1
# 3 megahit   1

# %% [markdown]
# ## Writing combined ALE results

# %%
out_file = file.path(work_dir, 'ALE_results.tsv')
ALE_res %>%
    write.table(file=out_file, sep='\t', quote=FALSE, row.names=FALSE)
cat('File written:', out_file, '\n')
# Out:
# File written: /ebio/abt3_projects/databases_no-backup/DeepMAsED/test_runs/n100_r5/ALE//ALE_results.tsv

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.1 LTS
#
# Matrix products: default
# BLAS: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRblas.so
# LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRlapack.so
#
# locale:
#  [1] LC_CTYPE=en_US.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_US.UTF-8        LC_COLLATE=en_US.UTF-8
#  [5] LC_MONETARY=en_US.UTF-8    LC_MESSAGES=en_US.UTF-8
#  [7] LC_PAPER=en_US.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_US.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] parallel  stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] bindrcpp_0.2.2          future.apply_1.0.0      future.batchtools_0.7.1
#  [4] future_1.9.0            doParallel_1.0.11       iterators_1.0.10
#  [7] foreach_1.4.4           data.table_1.11.4       ggplot2_3.0.0
# [10] tidyr_0.8.1             dplyr_0.7.6
#
# loaded via a namespace (and not attached):
#  [1] pbdZMQ_0.3-2      progress_1.2.0    tidyselect_0.2.4  repr_0.15.0
#  [5] purrr_0.2.4       listenv_0.7.0     colorspace_1.3-2  htmltools_0.3.6
#  [9] base64enc_0.1-3   rlang_0.2.1       pillar_1.2.2      glue_1.3.0
# [13] withr_2.1.1       rappdirs_0.3.1    uuid_0.1-2        bindr_0.1.1
# [17] plyr_1.8.4        stringr_1.3.1     munsell_0.5.0     gtable_0.2.0
# [21] codetools_0.2-15  evaluate_0.10.1   batchtools_0.9.11 IRdisplay_0.4.4
# [25] Rcpp_0.12.17      scales_0.5.0      backports_1.1.2   checkmate_1.8.5
# [29] IRkernel_0.8.12   jsonlite_1.5      fs_1.2.6          brew_1.0-6
# [33] hms_0.4.2         digest_0.6.15     stringi_1.2.3     grid_3.4.1
# [37] tools_3.4.1       magrittr_1.5      base64url_1.4     lazyeval_0.2.1
# [41] tibble_1.4.2      crayon_1.3.4      pkgconfig_2.0.1   prettyunits_1.0.2
# [45] assertthat_0.2.0  R6_2.2.2          globals_0.12.2    compiler_3.4.1
